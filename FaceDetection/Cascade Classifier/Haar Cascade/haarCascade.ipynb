# %%
  import cv2
  import matplotlib.pyplot as plt
  import time
  # %matplotlib inline

# %%
from google.colab import files

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml -P drive/gaze
# Out:
# --2021-02-01 10:54:38--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘drive/gaze/haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.05s
#
# 2021-02-01 10:54:38 (18.9 MB/s) - ‘drive/gaze/haarcascade_frontalface_default.xml’ saved [930127/930127]

# %%
cascades_path = 'drive/gaze/'

# %%
haar_face_cascade = cv2.CascadeClassifier(cascades_path + 'haarcascade_frontalface_default.xml')

# %%
def convertToRGB(img):
  return cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # cv2.cvtcolor is an OpenCV function which convert images to different color spaces.

# %%
def detect_face(f_cascade, colored_img, scale_factor = 1.1):
  img_copy = colored_img.copy()
  gray_image = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)
  faces = f_cascade.detectMultiScale(gray_image, scaleFactor = scale_factor, minNeighbors = 5)
  for(x, y, w, h) in faces:
    cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)
  return img_copy

# %%
upload = files.upload()
file1 = cv2.imread('image1.jpeg')
face_image1 = detect_face(haar_face_cascade, file1)
# Out:
#      <input type="file" id="files-cee5d3dd-76d3-461d-94ff-45895ae4b4eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cee5d3dd-76d3-461d-94ff-45895ae4b4eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image1.jpeg to image1.jpeg

# %%
plt.imshow(convertToRGB(face_image1))

# %%
upload = files.upload()
file2 = cv2.imread('image2.jfif')
face_image2 = detect_face(haar_face_cascade, file2, scale_factor= 1.1)
plt.imshow(convertToRGB(face_image2))
# Out:
#      <input type="file" id="files-fa5e3bb9-6c63-4c99-bc71-de84d873614b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa5e3bb9-6c63-4c99-bc71-de84d873614b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image2.jfif to image2 (1).jfif

# %%
upload = files.upload()
file2 = cv2.imread('image.jpeg')
face_image3 = detect_face(haar_face_cascade, file2, scale_factor= 1.5)
plt.imshow(convertToRGB(face_image3))
# Out:
#      <input type="file" id="files-bce9252a-bd5a-4ccd-97bb-35c5bde534d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bce9252a-bd5a-4ccd-97bb-35c5bde534d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.jpeg to image (2).jpeg
