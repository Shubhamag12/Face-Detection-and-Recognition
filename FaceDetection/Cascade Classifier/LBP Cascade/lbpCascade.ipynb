# %%
  import cv2
  import matplotlib.pyplot as plt
  import time
  # %matplotlib inline

# %%
from google.colab import files

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/lbpcascades/lbpcascade_frontalface.xml -P drive/gaze
# Out:
# --2021-02-01 11:22:51--  https://raw.githubusercontent.com/opencv/opencv/master/data/lbpcascades/lbpcascade_frontalface.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51856 (51K) [text/plain]
# Saving to: ‘drive/gaze/lbpcascade_frontalface.xml’
#
# lbpcascade_frontalf 100%[===================>]  50.64K  --.-KB/s    in 0.004s
#
# 2021-02-01 11:22:52 (12.0 MB/s) - ‘drive/gaze/lbpcascade_frontalface.xml’ saved [51856/51856]

# %%
cascades_path = 'drive/gaze/'

# %%
lbp_face_cascade = cv2.CascadeClassifier(cascades_path + 'lbpcascade_frontalface.xml')

# %%
def convertToRGB(img):
  return cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # cv2.cvtcolor is an OpenCV function which convert images to different color spaces.

# %%
def detect_face(f_cascade, colored_img, scale_factor = 1.1):
  img_copy = colored_img.copy()
  gray_image = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)
  faces = f_cascade.detectMultiScale(gray_image, scaleFactor = scale_factor, minNeighbors = 5)
  for(x, y, w, h) in faces:
    cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)
  return img_copy

# %%
upload = files.upload()
file2 = cv2.imread('image.jpeg')
face_image3 = detect_face(lbp_face_cascade, file2, scale_factor= 1.05)
plt.imshow(convertToRGB(face_image3))
# Out:
#      <input type="file" id="files-d8abd797-f121-428e-a9c9-2f6eb1c94be1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d8abd797-f121-428e-a9c9-2f6eb1c94be1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image.jpeg to image (3).jpeg

# %%
upload = files.upload()
file2 = cv2.imread('image1.jpeg')
face_image3 = detect_face(lbp_face_cascade, file2, scale_factor= 1.05)
plt.imshow(convertToRGB(face_image3))
# Out:
#      <input type="file" id="files-9a0bd976-f8c2-4e7b-b3bd-207e02b6d7d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a0bd976-f8c2-4e7b-b3bd-207e02b6d7d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image1.jpeg to image1 (1).jpeg

# %%
upload = files.upload()
file2 = cv2.imread('image2.jfif')
face_image3 = detect_face(haar_face_cascade, file2, scale_factor= 1.5)
plt.imshow(convertToRGB(face_image3))
# Out:
#      <input type="file" id="files-8764ac83-9f0e-4daa-99ad-8722a593f4be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8764ac83-9f0e-4daa-99ad-8722a593f4be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image2.jfif to image2 (3).jfif
